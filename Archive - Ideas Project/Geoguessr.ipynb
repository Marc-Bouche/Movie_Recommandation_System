# %%
git clone <repository-url> # Clone the repository
git checkout -b <branch-name>  # Create and switch to a new branch
# Out:
#   Cell In[2], line 1
#     git clone <repository-url> # Clone the repository
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

pd.set_option('display.max_rows', 500)
warnings.filterwarnings('ignore')

# %%
master_df = pd.read_csv("geoguessr-user-data-09-25-2024.csv")

# %%
master_df.head()
# Out:
#             nick                       created  isProUser        type  \
# 0     Bocodot640  2021-09-16T08:01:01.2670000Z      False  Registered
# 1    maxrmcneill  2016-01-21T12:26:34.0000000Z       True         Pro
# 2  Ruben Alcalde  2018-05-25T22:25:48.0890000Z      False  Registered
# 3          stars  2021-04-28T06:02:59.7340000Z      False  Registered
# 4            Max  2021-12-08T01:21:42.2850000Z       True       Basic
#
#    consumedTrial  isVerified                                    pinUrl  \
# 0          False       False  pin/5e676698c89e5126d8e21a1d725de220.png
# 1           True       False  pin/d3122cc602d07b175dc5e8705c58c2d5.png
# 2          False       False  pin/83f5b4a9fe9bbfefe0d01e9081ebaee5.png
# 3           True       False  pin/c8c1bde296b059c8771b795195875710.png
# 4           True       False  pin/095baacfc1d633b8c325888f90f610cc.png
#
#        pinAnchor  pinIsdefault                               fullBodyPin  ...  \
# 0  center-center         False  pin/cd6ca8abba11d30c5906362f9240b94a.png  ...
# 1  center-center         False  pin/79b28836d8f017b167e7e183ed954c33.png  ...
# 2  center-center         False  pin/fb6658ba801f83f7a81a7430e51a1818.png  ...
# 3  center-center         False  pin/0ec6c4a1c424f8d0a7e9f1a190764582.png  ...
# 4  center-center         False  pin/86fd60bea179bad089dae8fd482fc0b8.png  ...
#
#    divisionName rating  tier  divisionNumberBest  divisionPositionBest  \
# 0           NaN    NaN   NaN                 NaN                   NaN
# 1           NaN    NaN   NaN                 NaN                   NaN
# 2           NaN    NaN   NaN                 NaN                   NaN
# 3           NaN    NaN   NaN                 NaN                   NaN
# 4           NaN    NaN   NaN                 NaN                   NaN
#
#    divisionNameBest  divisionTierBest  gameModeRatingsStandardduels  \
# 0               NaN               NaN                           NaN
# 1               NaN               NaN                           NaN
# 2               NaN               NaN                           NaN
# 3               NaN               NaN                           NaN
# 4               NaN               NaN                           NaN
#
#    gameModeRatingsNomoveduels  gameModeRatingsNmpzduels
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
# [5 rows x 141 columns]

# %%
master_df.shape
# Out:
# (143560, 141)

# %%
master_df.isna().sum()
# Out:
# nick                                                  2
# created                                               0
# isProUser                                             0
# type                                                  0
# consumedTrial                                         0
# isVerified                                            0
# pinUrl                                               17
# pinAnchor                                             0
# pinIsdefault                                          0
# fullBodyPin                                           0
# color                                                 0
# countryCode                                       13281
# brLevel                                               0
# brDivision                                            0
# streakProgress                                   143560
# explorerProgress                                 143560
# dailyChallengeProgress                                0
# progressXp                                            0
# progressLevel                                         0
# progressLevelxp                                       0
# progressNextlevel                                     0
# progressNextlevelxp                                   0
# progressTitleId                                       0
# progressTitleTierid                                   0
# progressCompetitionmedalsBronze                       0
# progressCompetitionmedalsSilver                       0
# progressCompetitionmedalsGold                         0
# progressCompetitionmedalsPlatinum                     0
# competitiveElo_deprecated                             0
# competitiveRating_deprecated                          0
# competitiveLastratingchange_deprecated                0
# competitiveDivisionType_deprecated                    0
# competitiveDivisionStartrating_deprecated             0
# competitiveDivisionEndrating_deprecated               0
# competitiveOnleaderboard_deprecated                   0
# lastNameChange                                        0
# lastNickOrCountryChange                               0
# isBanned                                              0
# chatBan                                               0
# nameChangeAvailableAt                            142845
# avatarFullbodypath                                    0
# isBotUser                                             0
# suspendedUntil                                   143075
# wallet                                           143560
# flair                                                 0
# isCreator                                             0
# isAppAnonymous                                        0
# rankedTeamDuelsStandardNumgamesplayed                 0
# rankedTeamDuelsStandardNumwins                        0
# rankedTeamDuelsStandardWinratio                       0
# rankedTeamDuelsNoMoveNumgamesplayed                   0
# rankedTeamDuelsNoMoveNumwins                          0
# rankedTeamDuelsNoMoveWinratio                         0
# rankedTeamDuelsNmpzNumgamesplayed                     0
# rankedTeamDuelsNmpzNumwins                            0
# rankedTeamDuelsNmpzWinratio                           0
# rankedTeamDuelsTotalNumgamesplayed                    0
# rankedTeamDuelsTotalNumwins                           0
# rankedTeamDuelsTotalWinratio                          0
# battleRoyaleDistanceNumgamesplayed                    0
# battleRoyaleDistanceAvgposition                       0
# battleRoyaleDistanceNumwins                           0
# battleRoyaleDistanceWinratio                          0
# battleRoyaleDistanceAvgguessdistance                  0
# battleRoyaleDistanceNumguesses                        0
# battleRoyaleCountryNumgamesplayed                     0
# battleRoyaleCountryAvgposition                        0
# battleRoyaleCountryNumwins                            0
# battleRoyaleCountryWinratio                           0
# battleRoyaleCountryNumguesses                         0
# battleRoyaleCountryAvgcorrectguesses                  0
# battleRoyaleMedalsMedalcountgold                      0
# battleRoyaleMedalsMedalcountsilver                    0
# battleRoyaleMedalsMedalcountbronze                    0
# competitiveCityStreaksNumgamesplayed                  0
# competitiveCityStreaksAvgposition                     0
# competitiveCityStreaksNumwins                         0
# competitiveCityStreaksWinratio                        0
# competitiveCityStreaksNumguesses                      0
# competitiveCityStreaksAvgcorrectguesses               0
# competitiveStreaksMedalsMedalcountgold                0
# competitiveStreaksMedalsMedalcountsilver              0
# competitiveStreaksMedalsMedalcountbronze              0
# duelsNumgamesplayed                                   0
# duelsAvgposition                                      0
# duelsNumwins                                          0
# duelsWinratio                                         0
# duelsAvgguessdistance                                 0
# duelsNumguesses                                       0
# duelsNumflawlesswins                                  0
# duelsNoMoveNumgamesplayed                             0
# duelsNoMoveAvgposition                                0
# duelsNoMoveNumwins                                    0
# duelsNoMoveWinratio                                   0
# duelsNoMoveAvgguessdistance                           0
# duelsNoMoveNumguesses                                 0
# duelsNoMoveNumflawlesswins                            0
# duelsNmpzNumgamesplayed                               0
# duelsNmpzAvgposition                                  0
# duelsNmpzNumwins                                      0
# duelsNmpzWinratio                                     0
# duelsNmpzAvgguessdistance                             0
# duelsNmpzNumguesses                                   0
# duelsNmpzNumflawlesswins                              0
# duelsTotalNumgamesplayed                              0
# duelsTotalAvgposition                                 0
# duelsTotalNumwins                                     0
# duelsTotalWinratio                                    0
# duelsTotalAvgguessdistance                            0
# duelsTotalNumguesses                                  0
# duelsTotalNumflawlesswins                             0
# duelsMedalsMedalcountgold                             0
# duelsMedalsMedalcountsilver                           0
# duelsMedalsMedalcountbronze                           0
# lifeTimeXpProgressionXp                               0
# lifeTimeXpProgressionCurrentlevelLevel                0
# lifeTimeXpProgressionCurrentlevelXpstart              0
# lifeTimeXpProgressionNextlevelLevel                   0
# lifeTimeXpProgressionNextlevelXpstart                 0
# lifeTimeXpProgressionCurrenttitleId                   0
# lifeTimeXpProgressionCurrenttitleTierid               0
# lifeTimeXpProgressionCurrenttitleMinimumlevel         0
# lifeTimeXpProgressionCurrenttitleName                 0
# totalMedalsMedalcountgold                             0
# totalMedalsMedalcountsilver                           0
# totalMedalsMedalcountbronze                           0
# teamDuelsNumgamesplayed                               0
# teamDuelsNumwins                                      0
# teamDuelsWinratio                                     0
# perfectRounds                                         0
# divisionNumber                                   139188
# divisionName                                     139188
# rating                                           140306
# tier                                             139188
# divisionNumberBest                               139188
# divisionPositionBest                             139188
# divisionNameBest                                 139188
# divisionTierBest                                 139188
# gameModeRatingsStandardduels                     143412
# gameModeRatingsNomoveduels                       143192
# gameModeRatingsNmpzduels                         143421
# dtype: int64
