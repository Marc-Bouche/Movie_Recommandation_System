# %%
import pandas as pd
import requests
import time
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Load imbd movies dataset
url = '/Users/mbouch17/Desktop/IronHack/Labs &  Project/Project-3-Week-3/final_merged_file.csv'
df = pd.read_csv(url)
######### Year column #########
df['Year_y'] = np.where(df['Year_y'].isnull(), df['Year_x'], df['Year_y'])
df.drop('Year_x', axis=1, inplace=True)

######### Year column #########
# Merge Genre_x and Genre_y into a new column called 'Genre'
df['Genre'] = df['Genre_x'].fillna('') + df['Genre_y'].fillna('')
df['Genre'] = df['Genre'].str.strip()

df.drop('Genre_x', axis=1, inplace=True)
df.drop('Genre_y', axis=1, inplace=True)

######### Metascore column #########
df['Metascore_y'] = df['Metascore_y'].fillna(df['Metascore_x'])
df.drop(columns=['Metascore_x'], inplace=True)
df.rename(columns={'Metascore_y': 'Metascore'}, inplace=True)

######### Metascore column #########
df['Director_y'] = df['Director_y'].fillna(df['Director_x'])
df.drop(columns=['Director_x'], inplace=True)
df.rename(columns={'Director_y': 'Director'}, inplace=True)

df.columns = df.columns.str.replace(r'(_x_x|_x_y|_x|_y)$', '', regex=True)

######### imdbRating column #########
# Replace null values in 'imdbRating' with values from 'Rating'
df['imdbRating'] = df['imdbRating'].fillna(df['Rating'])
df.drop(columns=['Rating'], inplace=True)

######### Cast column #########
df['Cast'] = df['Cast'].fillna(df['Actors'])
df.drop('Actors', axis=1, inplace=True)

###### Runtime and Duration Merge #######
# Replace null values in 'Duration' with values from 'Runtime'
df['Runtime'] = df['Runtime'].str.replace('[^0-9.]', '', regex=True)
df['Runtime'] = pd.to_numeric(df['Runtime'])
df['Duration'] = df['Duration'].fillna(df['Runtime'])
df.drop(columns=['Runtime'], inplace=True)

# Drop rows where 'BoxOffice' is NaN or empty
df = df.dropna(subset=['BoxOffice'])
df = df[df['BoxOffice'] != '']


###Remove limits in columns and rows display###
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                                        Title Certificate  Duration  \
# 0                        10 Cloverfield Lane           A     103.0
# 1                                 12 Monkeys           A     129.0
# 2                           12 Years a Slave           A     134.0
# 4                             13 Going on 30          UA      98.0
# 5  13 Hours: The Secret Soldiers of Benghazi           A     144.0
#
#                                                 Cast    Votes  \
# 0  John Goodman, Mary Elizabeth Winstead, John Ga...  355,492
# 1  Bruce Willis, Madeleine Stowe, Brad Pitt, Jose...  647,448
# 2  Chiwetel Ejiofor, Michael Kenneth Williams, Mi...  742,226
# 4  Jennifer Garner, Mark Ruffalo, Judy Greer, And...  217,535
# 5  John Krasinski, Pablo Schreiber, James Badge D...  161,166
#
#                                          Description Review_Count  \
# 0  A young woman is held in an underground bunker...          565
# 1  In a future world devastated by disease, a con...          618
# 2  In the antebellum United States,Solomon Northu...          681
# 4  Unpopular schoolgirl Jenna Rink makes an unusu...          375
# 5  During an attack on a U.S. compound in Libya, ...          355
#
#                                  Review_Title  \
# 0                         10 Cloverfield Lane
# 1          these monkeys will go to heaven...
# 2  Slavery is an evil that should befall none
# 4                       Jennifer Garner rules
# 5          13 Hours that didn't have to be...
#
#                                               Review  \
# 0  Two months ago, no one knew that 10 Cloverfiel...
# 1  "Twelve monkeys"'s got all the elements to bec...
# 2  12 Years a Slave tells the true story of Solom...
# 4  It's impossible to imagine this film with anyo...
# 5  For the movie I gave it an 8. That's based on ...
#
#                                               Poster  Year  Rated  \
# 0  https://m.media-amazon.com/images/M/MV5BMjEzMj...  2016  PG-13
# 1  https://m.media-amazon.com/images/M/MV5BN2Y2OW...  1995      R
# 2  https://m.media-amazon.com/images/M/MV5BMjExMT...  2013      R
# 4  https://m.media-amazon.com/images/M/MV5BMjE1Nz...  2004  PG-13
# 5  https://m.media-amazon.com/images/M/MV5BYjY0OW...  2016      R
#
#                                                 Plot  Metascore  \
# 0  A young woman is held in an underground bunker...       76.0
# 1  In a future world devastated by disease, a con...       74.0
# 2  In the antebellum United States, Solomon North...       96.0
# 4  Unpopular schoolgirl Jenna Rink makes an unusu...       57.0
# 5  During an attack on a U.S. compound in Libya, ...       48.0
#
#            Director  imdbRating imdbVotes  \
# 0  Dan Trachtenberg         7.2   361,826
# 1     Terry Gilliam         8.0   651,903
# 2     Steve McQueen         8.1   750,182
# 4       Gary Winick         6.3   222,736
# 5       Michael Bay         7.3   164,085
#
#                                               Awards  \
# 0                           16 wins & 48 nominations
# 1  Nominated for 2 Oscars. 11 wins & 25 nominatio...
# 2     Won 3 Oscars. 244 wins & 337 nominations total
# 4                                     11 nominations
# 5         Nominated for 1 Oscar. 5 nominations total
#
#                          Country                                 Language  \
# 0                  United States                                  English
# 1                  United States  English, French, Latin, Spanish, German
# 2  United Kingdom, United States                                  English
# 4                  United States                      English, Portuguese
# 5           United States, Malta                          English, Arabic
#
#      BoxOffice Review Count Review Title  \
# 0  $72,082,998          NaN          NaN
# 1  $57,141,459          NaN          NaN
# 2  $56,671,993          NaN          NaN
# 4  $57,231,747          NaN          NaN
# 5  $52,853,219          NaN          NaN
#
#                                                Genre
# 0       Drama, Horror, MysteryDrama, Horror, Mystery
# 1  Mystery, Sci-Fi, ThrillerMystery, Sci-Fi, Thri...
# 2  Biography, Drama, HistoryBiography, Drama, His...
# 4   Comedy, Fantasy, RomanceComedy, Fantasy, Romance
# 5       Action, Drama, HistoryAction, Drama, History

# %%
df['GenreID'] = df['Title'] + '-' + df['Genre']

# Group by GenreID and calculate your desired statistics
genre_statistics = df.groupby('GenreID').agg({
    'imdbRating': 'mean',
    'imdbVotes': 'sum',
    'BoxOffice': 'sum'
}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 9
#       3 # Group by GenreID and calculate your desired statistics
#       4 genre_statistics = df.groupby('GenreID').agg({
#       5     'imdbRating': 'mean',
#       6     'imdbVotes': 'sum',
#       7     'BoxOffice': 'sum'
#       8 }).reset_index()
# ----> 9 df['columns']
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'columns'

# %%
# Table 1: Sorted by average rating and vote count (already sorted in previous steps)
print("Table 1: Sorted by Average Rating and Vote Count")
genre_statistics_df.round(2)
# Out:
# Table 1: Sorted by Average Rating and Vote Count
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Table 1: Sorted by average rating and vote count (already sorted in previous steps)
#       2 print("Table 1: Sorted by Average Rating and Vote Count")
# ----> 3 genre_statistics_df.round(2)
#
# NameError: name 'genre_statistics_df' is not defined

# %%
# Plot 1: Average IMDb Ratings by Genre
plt.figure(figsize=(8, 5))
sns.barplot(x='avg_rating', y='Genre', data=genre_stats)
plt.title('Average IMDb Ratings by Genre')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 3
#       1 # Plot 1: Average IMDb Ratings by Genre
#       2 plt.figure(figsize=(8, 5))
# ----> 3 sns.barplot(x='avg_rating', y='Genre', data=genre_stats)
#       4 plt.title('Average IMDb Ratings by Genre')
#       5 plt.show()
#
# NameError: name 'genre_stats' is not defined

# %%
# Table 3: Sorted by avg_box_office in descending order
genre_statistics_df['avg_box_office'] = genre_statistics_df['avg_box_office'].astype(str)
genre_statistics_df['avg_box_office'] = genre_statistics_df['avg_box_office'].replace({'\$': '', ',': ''}, regex=True).astype(float)
genre_stats_by_box_office = genre_statistics_df.sort_values(by='avg_box_office', ascending=False)
print("\nTable 3: Sorted by Average Box Office")
genre_stats_by_box_office.round(2)

# %%
# Table 3: Sorted by avg_box_office in descending order
genre_stats_by_box_office = genre_stats.sort_values(by='avg_box_office', ascending=False, key=lambda x: x.str.replace('[$,]', '', regex=True).astype(float))
print("\nTable 3: Sorted by Average Box Office")
genre_stats_by_box_office.round(2)

# %%
# Plot 2: Average Votes by Genre
plt.figure(figsize=(8, 5))
sns.barplot(x='avg_votes', y='Genre', data=genre_stats_by_votes)
plt.title('Average Votes by Genre')
plt.show()

# %%
# Plot 3: Average Box Office by Genre
plt.figure(figsize=(8, 5))
sns.barplot(x='avg_box_office_numeric', y='Genre', data=genre_stats)
plt.title('Average Box Office by Genre')
plt.show()
